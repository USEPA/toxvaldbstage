# %%
#Script to fill in file name field into clowder log based on how file appears in clowder

import time as t
import requests
import numpy as np
import pandas as pd
import os
from dotenv import load_dotenv #environment files for credentials. Make sure to pip install dotenv first


#environment file with credentials
load_dotenv()
#Script to fill in the file names from clowder, source, and subsource metadata fields
df = pd.read_excel(r"L:\PRIV\ToxValDB\Document Webscrape\pprtv_ornl\clowder_log_source_pprtv_ornl_20220727_temporary.xlsx")
api_key = os.environ.get('apiKey')
url = 'https://clowder.edap-cluster.com/api/files/'
source = 'PPRTV ORNL'
#These fields are blank for all files that were aquired in the webscrape
subsource = ''
doi = ''
hero_id = ''
dsstox_structure_id = ''

#Start loop in position 3, first entries in excel sheet are for the folder names which do not contain chemical info.
for i in range (3,len(df)):
#Fill in all of the static fields first
    df.loc[i,'file_name'] = ""
    df.loc[i,'source'] = source
    df.loc[i,'subsource'] = subsource
    df.loc[i,'doi'] = doi
    df.loc[i,'hero_id'] = hero_id
    df.loc[i,'dsstox_structure_id'] = dsstox_structure_id
#Access the clowder files
    clowder_id = df.loc[i,'uuid']
    t.sleep(0.5) #Courtesy sleep time
#Clowder API request to get data about the file connected to the clowder id accessed above
    response = requests.get(url+clowder_id+'/metadata', headers = {'X-API-Key': api_key})
    text = response.text
#Look only for the file name as it appears in clowder
#Note: This should be the same as the subDir2 field, but just in case we wrote this section
    start = text.index('filename')+11
    if '.pdf' in text:
        end = text.index('.pdf')+4
    if '.png' in text:
        end = text.index('.png')+4
#Put the file name in its location in the dataframe
    df.loc[i,'file_name'] = text[start:end]
print('All done!!')
# Out:
# All done!!

# %%
#Next, find the url for the chemical support pdf and put it in our dataframe
#This is ONLY FOR THE PDF SUPPORT FILES. For all screenshots, the url does not change.
#There were a few exceptions that may be problematic. To ensure that we get the correct url, we will go to the page we link
#and see if it exists (status code 200 or status code 404)

import time as t
import requests
import numpy as np
import pandas as pd

#df = pd.read_excel(r"C:\\Users\\mmille16\\desktop\\temp_clowder_log_final.xlsx")

#URLS necessary to access the files downloaded in the webscrape.
pdf_url = 'https://hhpprtv.ornl.gov/issue_papers/'
png_url = 'https://hhpprtv.ornl.gov/quickview/pprtv.php'

#Common punctuation and symbols that cause problems for the support pdf urls
punc = "',-()" 
brak = '[]'

for i in range (3,len(df)):
#URL only changes for pdf files. lets do them first
    file_name = df.loc[i,'file_name']
    if '.pdf' in file_name:
#Start by finding the chemical name. It is in the file name between 'ornl' and 'summary'
        chem_start = file_name.index('ornl')+5
        chem_end = file_name.index('summary')-1
        chem_name = file_name[chem_start:chem_end]
#Next, remove pesky punctuation and spaces
        chem_name = chem_name.replace(" ","")
        for char in chem_name:
            if char in punc:
                chem_name = chem_name.replace(char,"")
        t.sleep(0.5) #Courtesy sleep time
#Use requests to see if the url we create with the pdf url and chemcial name is valid
        response = requests.get(pdf_url+chem_name+'.pdf')
#One chemical needed to remove its brakets. Here is where we catch that exception.
        if response.status_code != 200:
            for char in chem_name:
                if char in brak:
                    chem_name = chem_name.replace(char,"")
            t.sleep(0.5)
#After removing brakets, try again, stop, and tell me which chemical needs more work (if any)
            response = requests.get(pdf_url+chem_name+'.pdf')
        if response.status_code != 200:
            print('the link for '+chem_name+' was not retrieved')
        else:
#Fill in the url section for the pdfs with the url we accessed in requests
            df.loc[i,'url'] = pdf_url+chem_name+'.pdf'
#Fill in the png urls (the drop down menu does not change the url used to get the screenshots)
    if '.png' in file_name:
        df.loc[i,'url'] = png_url
print('All done!!')
# Out:
# All done!!

# %%
#Script to fill in the year metadata fields as they appear on the webpage for each chemical
#First access the webpage for the chemicals, then find the year. It is located in one of the textboxes.
import time as t
import requests
import numpy as np
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.by import By

#df = pd.read_excel(r"C:\\Users\\mmille16\\desktop\\temp_clowder_log_final.xlsx")
#Initial set up of a headless selenium webdriver
Options = webdriver.ChromeOptions()
Options.headless = True
s=Service(r'C:\Users\mmille16\Documents\chromedriver.exe')
driver = webdriver.Chrome(service=s, options = Options)
URL = 'https://hhpprtv.ornl.gov/quickview/pprtv.php'
driver.get(URL)

for i in range(3,len(df)):
#Obtain the chemical name. It is between 'ornl' and 'summar' for support .pdfs and between 'ornl' and 'webpage' for .pngs. 
    file_name = df.loc[i,'file_name']
    if '.pdf' in file_name:
        chem_start = file_name.index('ornl')+5
        chem_end = file_name.index('summary')-1
    if '.png' in file_name:
        chem_start = file_name.index('ornl')+5
        chem_end = file_name.index('webpage')-1
    chem_name = file_name[chem_start:chem_end]
    t.sleep(0.5) #Courtesy sleep time before interacting with webpage
    
    #Select the dropdown menu option based on chemical name
    select = Select(driver.find_element(By.ID, "mySelect"))
    select.select_by_visible_text(chem_name)
    
    #Find the date field in the text box
    element = driver.find_element(By.TAG_NAME,'h4')
    #Fill in the year location with the year from the webpage
    df.loc[i,'year'] = element.text[-4:]
driver.quit()
print('All done!!!')
# Out:
# All done!!!

# %%
#Finally, lets get the study names. They are different from the file names for the pdfs and are nonexistent for the pngs.
#Using pdfminer six, we can read the first page of the pdf and look for the title.
#The title always starts with 'Provisional' but the ending can be a little hard to find. Check for 3 possibilities
#Ending can come at the end of the casrn carn in parentheses, at the beginning of "U.S.EPA", or at the beginning of "Superfund"
#Not all pdfs have some of these fields, so try-except is best for finding them

import time as t
import requests
import numpy as np
import pandas as pd
from pdfminer.high_level import extract_text
from pdfminer.high_level import extract_pages

#Open pandas dataframe
#df = pd.read_excel(r"C:\\Users\\mmille16\\desktop\\temp_clowder_log_final.xlsx")

#File path to pdfs
file_path = r"L:\\PRIV\ToxValDB\\Document Webscrape\\pprtv_ornl\\output\\support_pdfs\\"
for i in range(3,len(df)):
#Name of pdf in the file directory. Will use this to open the pdf in pdfminer six
    file_name = df.loc[i,'file_name']
    if '.pdf' in file_name:
    #Extract the text on the first page of the support pdf
        text = extract_text(file_path + file_name, page_numbers = [0])
    #Get rid of white space and new lines
        text = " ".join(text.split())
    #Start looking for title. It always starts with "Provisional"
        title_start = text.index('Provisional')
    #This is where we will stor the indicies of possible title endings
        arr = []
    #Looking for the index of the last set of parentheses and add it to the array
        reverse = text[::-1]
        try:
            last_par = len(text) - reverse.index(')')
            arr.append(last_par)
        except:
            pass
    #Look for "Superfund" an add its index to the array of possible endings
        try:
            superfund = text.index('Superfund')
            arr.append(superfund)
        except:
            pass
    #Look for "U.S. EPA" and add its index to the array of possible endings
        try:
            epa = text.index('U.S.')
            arr.append(epa)
        except:
            pass
    #Our title ends at the earliest index of the three possibilites
        title_end = min(arr)
        title = text[title_start:title_end]
    #Sanity check. Do not need to print out the titles every time.
        print(title)
    #Screenshots are not from pdf support documents and do not have titles that I am aware of.
    if '.png' in file_name:
        title = ""
    #All papers come from U.S.EPA
    author = 'U.S. Environmental Protection Agency'
    #Fill in the dataframe with the titles and authors in their respective locations.
    df.loc[i,'study_name'] = title
    df.loc[i,'author'] = author
print('All done!!!')
# Out:
# Provisional Peer-Reviewed Toxicity Values for Acenaphthene (CASRN 83-32-9)
# Provisional Peer Reviewed Toxicity Values for Acenaphthylene (CASRN 208-96-8)
# Provisional Peer-Reviewed Toxicity Values for Acetone Cyanohydrin (CASRN 75-86-5)
# Provisional Peer-Reviewed Toxicity Values for Acetophenone (CASRN 98-86-2)
# Provisional Peer Reviewed Toxicity Values for Acrolein (CASRN 107-02-8)
# Provisional Peer-Reviewed Toxicity Values for Acrylic Acid (CASRN 79-10-7)
# Provisional Peer Reviewed Toxicity Values for Adiponitrile (CASRN 111-69-3)
# Provisional Peer Reviewed Toxicity Values for Aldrin (CASRN 309-00-2)
# Provisional Peer Reviewed Toxicity Values for Alizarin Red Compounds (Various CASRNs)
# Provisional Peer-Reviewed Toxicity Values for Allyl alcohol (CASRN 107-18-6)
# Provisional Peer Reviewed Toxicity Values for Aluminum (CASRN 7429-90-5)
# Provisional Peer-Reviewed Toxicity Values for 4-Amino-2,6-dinitrotoluene (CASRN 19406-51-0)
# Provisional Peer-Reviewed Toxicity Values for 2-Amino-4,6-dinitrotoluene (CASRN 35572-78-2)
# Provisional Peer-Reviewed Toxicity Values for 3-Amino-4-chlorobenzotrifluoride (CASRN 121-50-6)
# Provisional Peer Reviewed Toxicity Values for m-Aminophenol (CASRN 591-27-5)
# Provisional Peer-Reviewed Toxicity Values for o-Aminophenol (CASRN 95-55-6)
# Provisional Peer Reviewed Toxicity Values for p-Aminophenol (CASRN 123-30-8)
# Provisional Peer Reviewed Toxicity Values for 4-Aminopyridine (CASRN 504-24-5)
# Provisional Peer Reviewed Toxicity Values for Ammonia (CASRN 7664-41-7)
# Provisional Peer-Reviewed Toxicity Values for Picric Acid (2,4,6-Trinitrophenol) (CASRN 88-89-1) and Ammonium Picrate (CASRN 131-74-8)
# Provisional Peer-Reviewed Toxicity Values for Ammonium Salts of Inorganic Phosphates: Monoammonium Phosphate (MAP) (CASRN 7722-76-1) Diammonium Phosphate (DAP) (CASRN 7783-28-0)
# Provisional Peer-Reviewed Toxicity Values for tert-Amyl Alcohol (CASRN 75-85-4)
# Provisional Peer Reviewed Toxicity Values for Aniline (CASRN 62-53-3)
# Provisional Peer Reviewed Toxicity Values for Anilinobenzothiazole (CASRN 1843-21-6)
# Provisional Peer-Reviewed Toxicity Values for Anthracene (CASRN 120-12-7)
# Provisional Peer-Reviewed Toxicity Values for 9,10-Anthraquinone (CASRN 84-65-1)
# Provisional Peer Reviewed Toxicity Values for Soluble Antimony Compounds (Various CASRNs)
# Provisional Peer Reviewed Toxicity Values for Antimony Trioxide (CASRN 1309-64-4)
# Provisional Peer-Reviewed Toxicity Values for Aroclor 5460 (CASRN 11126-42-4)
# Provisional Peer-Reviewed Toxicity Values for Azodicarbonamide (CASRN 123-77-3)
# Provisional Peer-Reviewed Toxicity Values for Benzaldehyde (CASRN 100-52-7)
# Provisional Peer-Reviewed Toxicity Values for Toluene-2,5-diamine (CASRN 95-70-5) and Compounds Toluene-2,5-diamine sulfate (6369-59-1) [also known as 1,4-Benzenediamine-2-methyl sulfate or 2-Methylbenzene-1,4-diamine sulfate (615-50-9)], Toluene-2,5-diamine dihydrochloride (615-45-2), and Toluene-2,5-diamine monohydrochloride (74612-12-7)
# Provisional Peer-Reviewed Toxicity Values for Benzenethiol (CASRN 108-98-5)
# Provisional Peer-Reviewed Toxicity Values for Benzene (CASRN 71-43-2)
# Provisional Peer-Reviewed Toxicity Values for 2,3-Benzofluorene (CASRN 243-17-4)
# Provisional Peer Reviewed Toxicity Values for Benzoic Acid (CASRN 65-85-0)
# Provisional Peer Reviewed Toxicity Values for Benzothiazole (CASRN 95-16-9)
# Provisional Peer-Reviewed Toxicity Values for Benzotrichloride (CASRN 98-07-7)
# Provisional Peer Reviewed Toxicity Values for Benzo[b]fluoranthene (CASRN 205-99-2)
# Provisional Peer-Reviewed Toxicity Values for Benzo[e]pyrene (BeP) (CASRN 192-97-2)
# Provisional Peer Reviewed Toxicity Values for Benzo[k]fluoranthene (CASRN 207-08-9)
# Provisional Peer-Reviewed Toxicity Values for Benzyl alcohol (CASRN 100-51-6)
# Provisional Peer Reviewed Toxicity Values for Benzyl chloride (CASRN 100-44-7)
# Provisional Peer Reviewed Toxicity Values Benz[a]anthracene (CASRN 56-55-3)
# Provisional Peer Reviewed Toxicity Values for Bifenox (CASRN 42576-02-3)
# Provisional Peer-Reviewed Toxicity Values for 1,1-Biphenyl (CASRN 92-52-4)
# Provisional Peer-Reviewed Toxicity Values for Bis(2-chloro-1-methylethyl)ether (CASRN 108-60-1)
# Provisional Peer Reviewed Toxicity Values for Bis(2-chloroethoxy)methane (CASRN 111-91-1)
# Provisional Peer-Reviewed Toxicity Values for Boron Trichloride (CASRN 10294-34-5)
# Provisional Peer-Reviewed Toxicity Values for 1-Bromo-2-Chloroethane (CASRN 107-04-0)
# Provisional Peer-Reviewed Toxicity Values for 1-Bromo-3-fluorobenzene (CASRN 1073-06-9)
# Provisional Peer-Reviewed Toxicity Values for 1-Bromo-4-Ethylbenzene (CASRN 1585-07-5)
# Provisional Peer-Reviewed Toxicity Values for 1-Bromo-4-fluorobenzene (CASRN 460-00-4)
# Provisional Peer-Reviewed Toxicity Values for 3-Bromoacetophenone (CASRN 2142-63-4)
# Provisional Peer-Reviewed Toxicity Values for Bromochloromethane (CASRN 74-97-5)
# Provisional Peer-Reviewed Toxicity Values for Bromodichloromethane (CASRN 75-27-4)
# Provisional Peer Reviewed Toxicity Values for 4-Bromodiphenyl ether (CASRN 101-55-3)
# Provisional Peer Reviewed Toxicity Values for Bromoform (CASRN 75-25-2)
# Provisional Peer Reviewed Toxicity Values for Bromomethane (CASRN 74-83-9)
# Provisional Peer-Reviewed Toxicity Values for 2-Bromopyridine (CASRN 109-04-6)
# Provisional Peer Reviewed Toxicity Values for sec-Butyl alcohol (CASRN 78-92-2)
# Provisional Peer Reviewed Toxicity Values for Butyl benzyl phthalate (CASRN 85-68-7)
# Provisional Peer-Reviewed Toxicity Values for tert-Butyl Formate (CASRN 762-75-4)
# Provisional Peer-Reviewed Toxicity Values for Butylated Hydroxytoluene (BHT) (CASRN 128-37-0)
# Provisional Peer-Reviewed Toxicity Values for n-Butylbenzene (CASRN 104-51-8)
# Provisional Peer-Reviewed Toxicity Values for sec-Butylbenzene (CASRN 135-98-8)
# Provisional Peer-Reviewed Toxicity Values for tert-Butylbenzene (CASRN 98-06-6)
# Provisional Peer Reviewed Toxicity Values for Mono-, Di- and Tri- Butyltin Compounds (Various CASRN)
# Provisional Peer Reviewed Toxicity Values for Mono-, Di- and Tri- Butyltin Compounds (Various CASRN)
# Provisional Peer Reviewed Toxicity Values for Mono-, Di- and Tri- Butyltin Compounds (Various CASRN)
# Provisional Peer-Reviewed Toxicity Values for Calcium Salts of Inorganic Phosphates (Multiple CASRNs)
# Provisional Peer-Reviewed Toxicity Values for Calcium Salts of Inorganic Phosphates (Multiple CASRNs)
# Provisional Peer Reviewed Toxicity Values for Carbazole (CASRN 86-74-8)
# Provisional Peer-Reviewed Toxicity Values for Carbonyl Sulfide (Carbon Oxide Sulfide) (CASRN 463-58-1)
# Provisional Peer-Reviewed Toxicity Values for 4-Chloro-2-methylaniline (CASRN 95-69-2)
# Provisional Peer-Reviewed Toxicity Values for 4-Chloro-3-Methylphenol (p-Chloro-m-Cresol) (CASRN 59-50-7)
# Provisional Peer Reviewed Toxicity Values for 2-Chloro-6-fluorophenol (CASRN 2040-90-6)
# Provisional Peer-Reviewed Toxicity Values for 2-Chloroacetaldehyde (CASRN 107-20-0)
# Provisional Peer Reviewed Toxicity Values for Chloroacetic Acid (CASRN 79-11-8)
# Provisional Peer Reviewed Toxicity Values for p-Chloroaniline (CASRN 106-47-8)
# Provisional Peer-Reviewed Toxicity Values for p-Chlorobenzenesulfonic Acid (CASRN 98-66-8)
# Provisional Peer Reviewed Toxicity Values for Chlorobenzene (CASRN 108-90-7)
# Provisional Peer-Reviewed Toxicity Values for 2-Chlorobenzoic Acid (CASRN 118-91-2)
# Provisional Peer Reviewed Toxicity Values for p-Chlorobenzoic acid (CASRN 74-11-3)
# Provisional Peer-Reviewed Toxicity Values for 3-Nitro-4-chlorobenzotrifluoride (CASRN 121-17-5)
# Provisional Peer Reviewed Toxicity Values for 4-Chlorobenzotrifluoride (CASRN 98-56-6)
# Provisional Peer Reviewed Toxicity Values for 1-Chlorobutane (CASRN 109-69-3)
# Provisional Peer Reviewed Toxicity Values for 2-Chlorobutane (CASRN 78-86-4)
# Provisional Peer Reviewed Toxicity Values for Chloroethane (CASRN 75-00-3)
# Provisional Peer-Reviewed Toxicity Values for 2-Chloroethanol (CASRN 107-07-3)
# Provisional Peer-Reviewed Toxicity Values for Chloromethane (CASRN 74-87-3)
# Provisional Peer-Reviewed Toxicity Values for 2-Chloronaphthalene (CASRN 91-58-7)
# Provisional Peer-Reviewed Toxicity Values for o-Chloronitrobenzene (2-Chloronitrobenzene) (CASRN 88-73-3)
# Provisional Peer-Reviewed Toxicity Values for p-Chloronitrobenzene (CASRN 100-00-5)
# Provisional Peer-Reviewed Toxicity Values for 1-Chlorooctadecane (CASRN 3386-33-2)
# Provisional Peer Reviewed Toxicity Values for 2-Chlorophenol (CASRN 95-57-8)
# Provisional Peer Reviewed Toxicity Values for 2-Chloropropane (CASRN 75-29-6)
# Provisional Peer-Reviewed Toxicity Values for o-Chlorotoluene (CASRN 95-49-8)
# Provisional Peer-Reviewed Toxicity Values for p-Chlorotoluene (CASRN 106-43-4)
# Provisional Peer Reviewed Toxicity Values for Chrysene (CASRN 218-01-9)
# Provisional Peer Reviewed Toxicity Values for Cobalt (CASRN 7440-48-4)
# Provisional Peer-Reviewed Toxicity Values for Complex Mixtures of Aliphatic and Aromatic Hydrocarbons (CASRN Various)
# Provisional Peer-Reviewed Toxicity Values for Coronene (CASRN 191-07-1)
# Provisional Peer-Reviewed Toxicity Values for trans-Crotonaldehyde (CASRN 123-73-9)
# Provisional Peer-Reviewed Toxicity Values for Cyanogen Bromide (CASRN 506-68-3)
# Provisional Peer-Reviewed Toxicity Values for Cyclohexane (CASRN 110-82-7)
# Provisional Peer-Reviewed Toxicity Values for Cyclohexanone (CASRN 108-94-1)
# Provisional Peer-Reviewed Toxicity Values for Cyclohexene (CASRN 110-83-8)
# Provisional Peer Reviewed Toxicity Values for o,p’-Dichlorodiphenyldichloroethane (o,p’-DDD) (CASRN 53-19-0)
# Provisional Peer-Reviewed Toxicity Values for p,p′-Dichlorodiphenyldichloroethane (p,p′-DDD) (CASRN 72-54-8)
# Provisional Peer-Reviewed Toxicity Values for p,p′-Dichlorodiphenyldichloroethylene (p,p′-DDE) (CASRN 72-55-9)
# Provisional Peer Reviewed Toxicity Values for o,p’-DDT (CASRN 789-02-6)
# Provisional Peer-Reviewed Toxicity Values for n-Decane (CASRN 124-18-5)
# Provisional Peer-Reviewed Toxicity Values for Ammonium Salts of Inorganic Phosphates: Monoammonium Phosphate (MAP) (CASRN 7722-76-1) Diammonium Phosphate (DAP) (CASRN 7783-28-0)
# Provisional Peer Reviewed Toxicity Values for Dibenzofuran (CASRN 132-64-9)
# Provisional Peer-Reviewed Toxicity Values for Dibenzothiophene (CASRN 132-65-0)
# Provisional Peer Reviewed Toxicity Values for 1,2-Dibromo-3-Chloropropane (CASRN 96-12-8)
# Provisional Peer-Reviewed Toxicity Values for 1,3-Dibromobenzene (CASRN 108-36-1)
# Provisional Peer-Reviewed Toxicity Values for Dibromochloromethane (CASRN 124-48-1)
# Provisional Peer-Reviewed Toxicity Values for Calcium Salts of Inorganic Phosphates (Multiple CASRNs)
# Provisional Peer Reviewed Toxicity Values for (mixed isomers) 1,4-Dichloro-2-butene (CASRN 764-41-0) cis-1,4-Dichloro-2-butene (CASRN 1476-11-5)
# Provisional Peer Reviewed Toxicity Values for (mixed isomers) 1,4-Dichloro-2-butene (CASRN 764-41-0) cis-1,4-Dichloro-2-butene (CASRN 1476-11-5)
# Provisional Peer Reviewed Toxicity Values for (mixed isomers) 1,4-Dichloro-2-butene (CASRN 764-41-0) cis-1,4-Dichloro-2-butene (CASRN 1476-11-5)
# Provisional Peer-Reviewed Toxicity Values for 4,4’-Dichlorobenzophenone (CASRN 90-98-2)
# Provisional Peer-Reviewed Toxicity Values for 3,4-Dichlorobenzotrifluoride (CASRN 328-84-7)
# Provisional Peer-Reviewed Toxicity Values for Dichlorodifluoromethane (CASRN 75-71-8)
# Provisional Peer Reviewed Toxicity Values for 1,1-Dichloroethane (CASRN 75-34-3)
# Provisional Peer-Reviewed Toxicity Values for 1,2-Dichloroethane (CASRN 107-06-2)
# Provisional Peer Reviewed Toxicity Values for 1,2-Dichloroethylene (mixture) (CASRN 540-59-0)
# Provisional Peer-Reviewed Toxicity Values for cis-1,2-Dichloroethylene (CASRN 156-59-2)
# Provisional Peer-Reviewed Toxicity Values for trans-1,2-Dichloroethylene (CASRN 156-60-5)
# Provisional Peer Reviewed Toxicity Values for 2,4-Dichlorophenol (CASRN 120-83-2)
# Provisional Peer-Reviewed Toxicity Values for 1,2-Dichloropropane (CASRN 78-87-5)
# Provisional Peer Reviewed Toxicity Values for 1,3-Dichloropropane (CASRN 142-28-9)
# Provisional Peer-Reviewed Toxicity Values for 2,2-Dichloropropane (CASRN 594-20-7)
# Provisional Peer-Reviewed Toxicity Values for 1,1-Dichloropropene (CASRN 563-58-6)
# Provisional Peer-Reviewed Toxicity Values for Dicyclohexylamine (CASRN 101-83-7)
# Provisional Peer-Reviewed Toxicity Values for Dicyclopentadiene (CASRN 77-73-6)
# Provisional Peer-Reviewed Toxicity Values for Diethanolamine (CASRN 111-42-2)
# Provisional Peer-Reviewed Toxicity Values for O,O-Diethyl phosphorodithioate (CASRN 298-06-6)
# Provisional Peer-Reviewed Toxicity Values for Diethylene Glycol Monobutyl Ether (DGBE, CASRN 112-34-5)
# Provisional Peer-Reviewed Toxicity Values for Diethylene Glycol Monoethyl Ether (DGEE) (CASRN 111-90-0)
# Provisional Peer-Reviewed Toxicity Values for Diethylene Glycol Monomethyl Ether (CASRN 111-77-3)
# Provisional Peer Reviewed Toxicity Values for Diethylformamide (CASRN 617-84-5)
# Provisional Peer-Reviewed Toxicity Values for 2,2-Difluoropropane (CASRN 420-45-1)
# Provisional Peer-Reviewed Toxicity Values for Diisopropyl ether (CASRN 108-20-3)
# Provisional Peer-Reviewed Toxicity Values for Diisopropyl Methylphosphonate (CASRN 1445-75-6)
# Provisional Peer-Reviewed Toxicity Values for 3,3′-Dimethoxybenzidine (CASRN 119-90-4)
# Provisional Peer Reviewed Toxicity Values for Dimethyl methylphosphonate (CASRN 756-79-6)
# Provisional Peer Reviewed Toxicity Values for Dimethyl sulfide (CASRN 75-18-3)
# Provisional Peer-Reviewed Toxicity Values for 2,4-Dimethylaniline (CASRN 95-68-1)
# Provisional Peer-Reviewed Toxicity Values for N,N-Dimethylaniline (CASRN 121-69-7)
# Provisional Peer Reviewed Toxicity Values for 3,3’-Dimethylbenzidine (CASRN 119-93-7)
# Provisional Peer-Reviewed Toxicity Values for n,n-Dimethylcyclohexylamine (CASRN 98-94-2)
# Provisional Peer Reviewed Toxicity Values for Dimethylformamide (CASRN 68-12-2)
# Provisional Peer-Reviewed Toxicity Values for 1,1-Dimethylhydrazine (CASRN 57-14-7)
# Provisional Peer Reviewed Toxicity Values for Dimethylmercury (CASRN 593-74-8)
# Provisional Peer Reviewed Toxicity Values for Dimethylphenethylamine (Phentermine) (CASRN 122-09-8)
# Provisional Peer Reviewed Toxicity Values for 2,4-Dimethylphenol (CASRN 105-67-9)
# Provisional Peer Reviewed Toxicity Values for Dimethyl phthalate (CASRN 131-11-3)
# Provisional Peer-Reviewed Toxicity Values for 4,6-Dinitro-o-cresol (CASRN 534-52-1)
# Provisional Peer-Reviewed Toxicity Values for 3,5-Dinitroaniline (CASRN 618-87-1)
# Provisional Peer Reviewed Toxicity Values for 1,2-Dinitrobenzene (o-Dinitrobenzene) (CASRN 528-29-0)
# Provisional Peer Reviewed Toxicity Values for 1,4-Dinitrobenzene (p-Dinitrobenzene) (CASRN 100-25-4)
# Provisional Peer Reviewed Toxicity Values for 2,4-Dinitrophenol (CASRN 51-28-5)
# Provisional Peer-Reviewed Toxicity Values for N,N-Dinitrosopentamethylenetetramine (CASRN 101-25-7)
# Provisional Peer-Reviewed Toxicity Values for 2,6-Dinitrotoluene (CASRN 606-20-2)
# Provisional Peer-Reviewed Toxicity Values for Technical Grade Dinitrotoluene (CASRN 25321-14-6)
# Provisional Peer Reviewed Toxicity Values for Dinoseb (CASRN 88-85-7)
# Provisional Peer-Reviewed Toxicity Values for Diphenyl Ether (CASRN 101-84-8)
# Provisional Peer-Reviewed Toxicity Values for Diphenyl sulfone (CASRN 127-63-9)
# Provisional Peer-Reviewed Toxicity Values for N,N-Diphenyl-1,4-Benzenediamine (CASRN 74-31-7)
# Provisional Peer-Reviewed Toxicity Values for Diphenylamine (CASRN 122-39-4)
# Provisional Peer Reviewed Toxicity Values for Disulfoton (CASRN 298-04-4)
# Provisional Peer-Reviewed Toxicity Values for Diundecyl Phthalate (CASRN 3648-20-2)
# Provisional Peer-Reviewed Toxicity Values for Endosulfan Sulfate (CASRN 1031-07-8)
# Provisional Peer-Reviewed Toxicity Values for Endosulfan (CASRN 115-29-7)
# Provisional Peer Reviewed Toxicity Values for Endrin aldehyde (CASRN 7421-93-4)
# Provisional Peer-Reviewed Toxicity Values for Endrin Ketone (CASRN 53494-70-5)
# Provisional Peer Reviewed Toxicity Values for Endrin (CASRN 72-20-8)
# Provisional Peer Reviewed Toxicity Values for Epichlorohydrin (CASRN 106-89-8)
# Provisional Peer-Reviewed Toxicity Values for Ethoxyethanol Acetate (CASRN 111-15-9)
# Provisional Peer-Reviewed Toxicity Values for 2-Ethoxyethanol (CASRN 110-80-5)
# Provisional Peer-Reviewed Toxicity Values for Ethyl Acetate (CASRN 141-78-6)
# Provisional Peer-Reviewed Toxicity Values for Ethyl Acrylate (CASRN 140-88-5)
# Provisional Peer Reviewed Toxicity Values for Ethyl ether (Diethyl ether) (CASRN 60-29-7)
# Provisional Peer-Reviewed Toxicity Values for Ethyl Methacrylate (CASRN 97-63-2)
# Provisional Peer-Reviewed Toxicity Values for Ethylbenzene (CASRN 100-41-4)
# Provisional Peer-Reviewed Toxicity Values for Ethylene Cyanohydrin (CASRN 109-78-4)
# Provisional Peer Reviewed Toxicity Values for Ethylene Diamine (CASRN 107-15-3)
# Provisional Peer-Reviewed Toxicity Values for 2-Ethylhexanol (CASRN 104-76-7)
# Provisional Peer-Reviewed Toxicity Values for Fluoranthene (CASRN 206-44-0)
# Provisional Peer Reviewed Toxicity Values for Fluorene (CASRN 86-73-7)
# Provisional Peer-Reviewed Toxicity Values for Fluorobenzene (CASRN 462-06-6)
# Provisional Peer Reviewed Toxicity Values for 2-Fluorobiphenyl (CASRN 321-60-8)
# Provisional Peer Reviewed Toxicity Values for 2-Fluorophenol (CASRN 367-12-4)
# Provisional Peer-Reviewed Toxicity Values for Formic Acid (CASRN 64-18-6)
# Provisional Peer-Reviewed Toxicity Values for Stable (Nonradioactive) Gadolinium (CASRN 7440-54-2) and Soluble Salts
# Provisional Peer-Reviewed Toxicity Values for Glycidaldehyde (CASRN 765-34-4)
# Provisional Peer-Reviewed Toxicity Values for Guanidine Compounds (CASRN 113-00-8 Guanidine) (CASRN 506-93-4 Guanidine Nitrate) (CASRN 50-01-1 Guanidine Chloride)
# Provisional Peer-Reviewed Toxicity Values for Guanidine Compounds (CASRN 113-00-8 Guanidine) (CASRN 506-93-4 Guanidine Nitrate) (CASRN 50-01-1 Guanidine Chloride)
# Provisional Peer-Reviewed Toxicity Values for Guanidine Compounds (CASRN 113-00-8 Guanidine) (CASRN 506-93-4 Guanidine Nitrate) (CASRN 50-01-1 Guanidine Chloride)
# Provisional Peer-Reviewed Toxicity Values for n-Heptanal (CASRN 111-71-7)
# Provisional Peer-Reviewed Toxicity Values for n-Heptane (CASRN 142-82-5)
# Provisional Peer-Reviewed Toxicity Values for Hexachlorobenzene (CASRN 118-74-1)
# Provisional Peer Reviewed Toxicity Values for Hexachlorobutadiene (CASRN 87-68-3)
# Provisional Peer Reviewed Toxicity Values for delta-Hexachlorocyclohexane (CASRN 319-86-8)
# Provisional Peer Reviewed Toxicity Values for Hexadecanoic acid (CASRN 57-10-3)
# Provisional Peer-Reviewed Toxicity Values for Hexamethylphosphoramide (CASRN 680-31-9)
# Provisional Peer-Reviewed Toxicity Values for Commercial or Practical Grade Hexane
# Provisional Peer-Reviewed Provisional Subchronic Toxicity Values for n-Hexane (CASRN 110-54-3)
# Provisional Peer Reviewed Toxicity Values for Hexanedioic acid (CASRN 124-04-9)
# Provisional Peer-Reviewed Toxicity Values for Hydrazine (CASRN 302-01-2)
# Provisional Peer-Reviewed Toxicity Values for Hydroquinone (CASRN 123-31-9)
# Provisional Peer Reviewed Toxicity Values for Indeno[1,2,3-cd)pyrene (CASRN 193-39-5)
# Provisional Peer-Reviewed Toxicity Values for Iodomethane (Methyl Iodide) (CASRN 74-88-4)
# Provisional Peer Reviewed Toxicity Values for Iron and Compounds (CASRN 7439-89-6)
# Provisional Peer-Reviewed Toxicity Values for Iron Sulfide (CASRN 11126-12-8)
# Provisional Peer Reviewed Toxicity Values for Isobutanol (CASRN 78-83-1)
# Provisional Peer-Reviewed Toxicity Values for Isopropanol (CASRN 67-63-0)
# Provisional Peer-Reviewed Toxicity Values for p-Isopropyltoluene (CASRN 99-87-6)
# Provisional Peer-Reviewed Toxicity Values for Lactonitrile (CASRN 78-97-7)
# Provisional Peer-Reviewed Toxicity Values for Stable (Nonradioactive) Soluble Lanthanum (CASRN 7439-91-0)
# Provisional Peer-Reviewed Toxicity Values for Stable (Nonradioactive) Soluble Lanthanum (CASRN 7439-91-0)
# Provisional Peer-Reviewed Toxicity Values for Stable (Nonradioactive) Soluble Lanthanum (CASRN 7439-91-0)
# Provisional Peer-Reviewed Toxicity Values for Stable (Nonradioactive) Soluble Lanthanum (CASRN 7439-91-0)
# Provisional Peer-Reviewed Toxicity Values for Stable (Nonradioactive) Soluble Lanthanum (CASRN 7439-91-0)
# Provisional Peer-Reviewed Toxicity Values for Lewisite (CASRN 541-25-3)
# Provisional Peer Reviewed Toxicity Values for Lithium (CASRN 7439-93-2)
# Provisional Peer-Reviewed Toxicity Values for Stable (Nonradioactive) Soluble Lutetium (CASRN 7439-94-3)
# Provisional Peer Reviewed Toxicity Values for Malononitrile (CASRN 109-77-3)
# Provisional Peer-Reviewed Toxicity Values for 2-Mercaptobenzothiazole (CASRN 149-30-4)
# Provisional Peer Reviewed Toxicity Values for Mercuric sulfide (CASRN 1344-48-5)
# Provisional Peer-Reviewed Toxicity Values for Methacrylonitrile (CASRN 126-98-7)
# Provisional Peer-Reviewed Toxicity Values for 2-Methoxyethanol (CASRN 109-86-4) and 2-Methoxyethanol Acetate (CASRN 110-49-6)
# Provisional Peer-Reviewed Toxicity Values for 2-Methoxyethanol (CASRN 109-86-4) and 2-Methoxyethanol Acetate (CASRN 110-49-6)
# Provisional Peer-Reviewed Toxicity Values for Methyl Acetate (CASRN 79-20-9)
# Provisional Peer-Reviewed Toxicity Values for Methyl Acrylate (CASRN 96-33-3)
# Provisional Peer-Reviewed Toxicity Values for n-Methyl Dicyclohexylamine (CASRN 7560-83-0)
# Provisional Peer-Reviewed Toxicity Values for Methyl Hydrazine (CASRN 60-34-4)
# Provisional Peer Reviewed Toxicity Values for Methyl Mercaptan (CASRN 74-93-1)
# Provisional Peer-Reviewed Toxicity Values for Methyl phosphonic acid (CASRN 993-13-5)
# Provisional Peer-Reviewed Toxicity Values for 4-Methyl-2-pentanol (CASRN 108-11-2)
# Provisional Peer-Reviewed Toxicity Values for 2-Methyl-5-Nitroaniline (CASRN 99-55-8)
# Provisional Peer Reviewed Toxicity Values for N-Methylaniline (CASRN 100-61-8)
# Provisional Peer-Reviewed Toxicity Values for Toluene-2,5-diamine (CASRN 95-70-5) and Compounds Toluene-2,5-diamine sulfate (6369-59-1) [also known as 1,4-Benzenediamine-2-methyl sulfate or 2-Methylbenzene-1,4-diamine sulfate (615-50-9)], Toluene-2,5-diamine dihydrochloride (615-45-2), and Toluene-2,5-diamine monohydrochloride (74612-12-7)
# Provisional Peer-Reviewed Toxicity Values for Methylcyclohexane (CASRN 108-87-2)
# Provisional Peer-Reviewed Toxicity Values for n-Methylcyclohexylamine (CAS No. 100-60-7)
# Provisional Peer-Reviewed Toxicity Values for Methylcyclopentane (CASRN 96-37-7)
# Provisional Peer-Reviewed Toxicity Values for Methylene bromide (CASRN 74-95-3)
# Provisional Peer Reviewed Toxicity Values for 4,4'-Methylenebis (2-chloroaniline) (CASRN 101-14-4)
# Provisional Peer Reviewed Toxicity Values for 1-Methylnaphthalene (CASRN 90-12-0)
# Provisional Peer Reviewed Toxicity Values for 2-Methylnaphthalene (CASRN 91-57-6)
# Provisional Peer-Reviewed Toxicity Values for 2-Methylphenol (CASRN 95-48-7)
# Provisional Peer-Reviewed Toxicity Values for 3-Methylphenol (CASRN 108-39-4)
# Provisional Peer-Reviewed Toxicity Values for 4-Methylphenol (p-Cresol) (CASRN 106-44-5)
# Provisional Peer-Reviewed Toxicity Values for Midrange Aliphatic Hydrocarbon Streams
# Provisional Peer-Reviewed Toxicity Values for Ammonium Salts of Inorganic Phosphates: Monoammonium Phosphate (MAP) (CASRN 7722-76-1) Diammonium Phosphate (DAP) (CASRN 7783-28-0)
# Provisional Peer-Reviewed Toxicity Values for Calcium Salts of Inorganic Phosphates (Multiple CASRNs)
# Provisional Peer-Reviewed Toxicity Values for High Flash Aromatic Naphtha (CASRNs 64742-95-6 and 88845-25-4)
# Provisional Peer-Reviewed Toxicity Values for 2-Naphthylamine (CASRN 91-59-8)
# Provisional Peer-Reviewed Toxicity Values for Stable (Nonradioactive) Neodymium Chloride (CASRN 10024-93-8)
# Provisional Peer Reviewed Toxicity Values for Nicotinonitrile (CASRN 100-54-9)
# Provisional Peer-Reviewed Toxicity Values for 2-Nitroaniline (CASRN 88-74-4)
# Provisional Peer-Reviewed Toxicity Values for 3-Nitroaniline (CASRN 99-09-2)
# Provisional Peer Reviewed Toxicity Values for 4-Nitroaniline (CASRN 100-01-6)
# Provisional Peer-Reviewed Toxicity Values for Nitrocellulose (CASRN 9004-70-0)
# Provisional Peer-Reviewed Toxicity Values for 2-Nitrodiphenylamine (CASRN 119-75-5)
# Provisional Peer-Reviewed Toxicity Values for Nitrofen (CASRN 1836-75-5)
# Provisional Peer Reviewed Toxicity Values for Nitroglycerin (CASRN 55-63-0)
# Provisional Peer Reviewed Toxicity Values for Nitroguanidine (CASRN 556-88-7)
# Provisional Peer-Reviewed Toxicity Values for Nitromethane (CASRN 75-52-5)
# Provisional Peer Reviewed Toxicity Values for 2-Nitrophenol (CASRN 88-75-5)
# Provisional Peer Reviewed Toxicity Values for p- Nitrophenol (CASRN 100-02-7)
# Provisional Peer-Reviewed Toxicity Values for 2-Nitropropane (CASRN 79-46-9)
# Provisional Peer Reviewed Toxicity Values for N-Nitrosodimethylamine (CASRN 62-75-9)
# Provisional Peer Reviewed Toxicity Values for N-Nitrosodiphenylamine (CASRN 86-30-6)
# Provisional Peer-Reviewed Toxicity Values for N-Nitrosopyrrolidine (CASRN 930-55-2)
# Provisional Peer-Reviewed Toxicity Values for m-Nitrotoluene (CASRN 99-08-1)
# Provisional Peer Reviewed Toxicity Values for o-Nitrotoluene (2-Nitrotoluene) (CASRN 88-72-2)
# Provisional Peer Reviewed Toxicity Values for p-Nitrotoluene (4-Nitrotoluene) (CASRN 99-99-0)
# Provisional Peer-Reviewed Toxicity Values for n-Nonane (CASRN 111-84-2)
# Provisional Peer Reviewed Toxicity Values for Octadecanoic Acid (Stearic Acid) (CASRN 57-11-4)
# Provisional Peer-Reviewed Toxicity Values for Octahydrotrimethylmethylethylphenanthrenol (CASRN 511-15-9)
# Provisional Peer-Reviewed Toxicity Values for Di-n-octyl Phthalate (CASRN 117-84-0)
# Provisional Peer-Reviewed Toxicity Values for Mixtures of 1,2,3,4,5-Pentabromo-6-Chlorocyclohexane (CASRN 87-84-3)
# Provisional Peer Reviewed Toxicity Values for Pentachloroethane (CASRN 76-01-7)
# Provisional Peer-Reviewed Toxicity Values for Pentaerythritol Tetranitrate (PETN) (CASRN 78-11-5)
# Provisional Peer-Reviewed Toxicity Values for Pentamethyl dipropylenetriamine (CASRN 3855-32-1)
# Provisional Peer-Reviewed Toxicity Values for Pentamethylphosphoramide (PMPA) (CASRN 10159-46-3)
# Provisional Peer-Reviewed Toxicity Values for n-Pentane (CASRN 109-66-0)
# Provisional Peer-Reviewed Toxicity Values for Perfluorobutane Sulfonic Acid (CASRN 375-73-5) and Related Compound Potassium Perfluorobutane Sulfonate (CASRN 29420-49-3)
# Provisional Peer-Reviewed Toxicity Values for Perfluorobutane Sulfonic Acid (CASRN 375-73-5) and Related Compound Potassium Perfluorobutane Sulfonate (CASRN 29420-49-3)
# Provisional Peer Reviewed Toxicity Values for Perylene (CASRN 198-55-0)
# Provisional Peer-Reviewed Toxicity Values for Phenanthrene (CASRN 85-01-8)
# Provisional Peer-Reviewed Toxicity Values for Phenothiazine (CASRN 92-84-2)
# Provisional Peer-Reviewed Toxicity Values for Phenyl isothiocyanate (CASRN 103-72-0)
# Provisional Peer-Reviewed Toxicity Values for o-Phenylenediamine (CASRN 95-54-5)
# Provisional Peer-Reviewed Toxicity Values for p-Phenylenediamine (CASRN 106-50-3)
# Provisional Peer Reviewed Toxicity Values for Phosphorus pentoxide (CASRN 1314-56-3)
# Provisional Peer Reviewed Toxicity Values for m-Phthalic acid (CASRN 121-91-5)
# Provisional Peer Reviewed Toxicity Values for o-Phthalic acid (CASRN 88-99-3)
# Provisional Peer-Reviewed Toxicity Values for p-Phthalic Acid (Terephthalic Acid) (CASRN 100-21-0)
# Provisional Peer-Reviewed Toxicity Values for Picramic Acid (CASRN 96-91-3)
# Provisional Peer-Reviewed Toxicity Values for Picric Acid (2,4,6-Trinitrophenol) (CASRN 88-89-1) and Ammonium Picrate (CASRN 131-74-8)
# Provisional Peer-Reviewed Toxicity Values for Perfluorobutane Sulfonic Acid (CASRN 375-73-5) and Related Compound Potassium Perfluorobutane Sulfonate (CASRN 29420-49-3)
# Provisional Peer-Reviewed Toxicity Values for Stable (Nonradioactive) Praseodymium Chloride (CASRN 10361-79-2)
# Provisional Peer Reviewed Toxicity Values for Promethium (CASRN 7440-12-2)
# Provisional Peer-Reviewed Toxicity Values for 3-(N,N-Dimethylamino)propionitrile (CASRN 1738-25-6)
# Provisional Peer Reviewed Toxicity Values for n-Propyl alcohol (CASRN 71-23-8)
# Provisional Peer-Reviewed Toxicity Values for n-Propylbenzene (CASRN 103-65-1)
# Provisional Peer-Reviewed Toxicity Values for Propylene Glycol Monoethyl Ether (Alpha Isomer [CASRN 52125-53-8] and Beta Isomer [CASRN 1569-02-4])
# Provisional Peer-Reviewed Toxicity Values for Propylene Glycol Monoethyl Ether (Alpha Isomer [CASRN 52125-53-8] and Beta Isomer [CASRN 1569-02-4])
# Provisional Peer Reviewed Toxicity Values for Propylene glycol (CASRN 57-55-6)
# Provisional Peer Reviewed Toxicity Values for Prussian Blue (Ferric Ferrocyanide) (CASRN 14038-43-8)
# Provisional Peer Reviewed Toxicity Values for Pyrene (CASRN 129-00-0)
# Provisional Peer-Reviewed Toxicity Values for Rubidium Compounds (CASRN 7440-17-7, Rubidium) (CASRN 7791-11-9, Rubidium Chloride) (CASRN 1310-82-3, Rubidium Hydroxide) (CASRN 7790-29-6, Rubidium Iodide)
# Provisional Peer-Reviewed Toxicity Values for Rubidium Compounds (CASRN 7440-17-7, Rubidium) (CASRN 7791-11-9, Rubidium Chloride) (CASRN 1310-82-3, Rubidium Hydroxide) (CASRN 7790-29-6, Rubidium Iodide)
# Provisional Peer-Reviewed Toxicity Values for Rubidium Compounds (CASRN 7440-17-7, Rubidium) (CASRN 7791-11-9, Rubidium Chloride) (CASRN 1310-82-3, Rubidium Hydroxide) (CASRN 7790-29-6, Rubidium Iodide)
# Provisional Peer-Reviewed Toxicity Values for Rubidium Compounds (CASRN 7440-17-7, Rubidium) (CASRN 7791-11-9, Rubidium Chloride) (CASRN 1310-82-3, Rubidium Hydroxide) (CASRN 7790-29-6, Rubidium Iodide)
# Provisional Peer-Reviewed Toxicity Values for Stable (Nonradioactive) Samarium Chloride (CASRN 10361-82-7) and Stable (Nonradioactive) Samarium Nitrate (CASRN 10361-83-8)
# Provisional Peer-Reviewed Toxicity Values for Stable (Nonradioactive) Samarium Chloride (CASRN 10361-82-7) and Stable (Nonradioactive) Samarium Nitrate (CASRN 10361-83-8)
# Provisional Peer-Reviewed Toxicity Values for Selenourea (CASRN 630-10-4)
# Provisional Peer-Reviewed Toxicity Values for Soluble Tungsten Compounds (Various CASRNs)
# Provisional Peer-Reviewed Toxicity Values for Soluble Tungsten Compounds (Various CASRNs)
# Provisional Peer Reviewed Toxicity Values for Soluble Antimony Compounds (Various CASRNs)
# Provisional Peer Reviewed Toxicity Values for Soluble Antimony Compounds (Various CASRNs)
# Provisional Peer-Reviewed Toxicity Values for Stearyl Acetate (CASRN 822-23-1)
# Provisional Peer-Reviewed Toxicity Values for Styrene-Acrylonitrile (SAN) Trimer (Various CASRNs)
# Provisional Peer-Reviewed Toxicity Values for Styrene-Acrylonitrile (SAN) Trimer (Various CASRNs)
# Provisional Peer-Reviewed Toxicity Values for Sulfolane (CASRN 126-33-0)
# Provisional Peer-Reviewed Toxicity Values for 1,1’-Sulfonylbis(4-chlorobenzene) (CASRN 80-07-9)
# Provisional Peer-Reviewed Toxicity Values for 1,2,4,5-Tetrachlorobenzene (CASRN 95-94-3)
# Provisional Peer-Reviewed Toxicity Values for 1,1,1,2-Tetrachloroethane (CASRN 630-20-6)
# Provisional Peer-Reviewed Toxicity Values for p-α,α,α-Tetrachlorotoluene (CASRN 5216-25-1)
# Provisional Peer Reviewed Toxicity Values for Tetrahydrothiophene (CASRN 110-01-0)
# Provisional Peer Reviewed Toxicity Values for Tetramethylcyclohexane (CASRN 30501-43-0)
# Provisional Peer-Reviewed Toxicity Values for N,N,N′,N″-Tetramethylphosphoramide (TMPA) (CASRN 16853-36-4)
# Provisional Peer-Reviewed Toxicity Values for Thallium and Compounds Metallic Thallium (7440-28-0), Thallium (I) acetate (563-68-8), Thallium (I) carbonate (6533-73-9), Thallium (I) chloride (7791-12-0), Thallium (I) nitrate (10102-45-1), and Thallium (I) sulfate (7446-18-6)
# Provisional Peer-Reviewed Toxicity Values for Thallium and Compounds Metallic Thallium (7440-28-0), Thallium (I) acetate (563-68-8), Thallium (I) carbonate (6533-73-9), Thallium (I) chloride (7791-12-0), Thallium (I) nitrate (10102-45-1), and Thallium (I) sulfate (7446-18-6)
# Provisional Peer-Reviewed Toxicity Values for Thallium and Compounds Metallic Thallium (7440-28-0), Thallium (I) acetate (563-68-8), Thallium (I) carbonate (6533-73-9), Thallium (I) chloride (7791-12-0), Thallium (I) nitrate (10102-45-1), and Thallium (I) sulfate (7446-18-6)
# Provisional Peer-Reviewed Toxicity Values for Thallium and Compounds Metallic Thallium (7440-28-0), Thallium (I) acetate (563-68-8), Thallium (I) carbonate (6533-73-9), Thallium (I) chloride (7791-12-0), Thallium (I) nitrate (10102-45-1), and Thallium (I) sulfate (7446-18-6)
# Provisional Peer-Reviewed Toxicity Values for Thallium and Compounds Metallic Thallium (7440-28-0), Thallium (I) acetate (563-68-8), Thallium (I) carbonate (6533-73-9), Thallium (I) chloride (7791-12-0), Thallium (I) nitrate (10102-45-1), and Thallium (I) sulfate (7446-18-6)
# Provisional Peer-Reviewed Toxicity Values for Thallium and Compounds Metallic Thallium (7440-28-0), Thallium (I) acetate (563-68-8), Thallium (I) carbonate (6533-73-9), Thallium (I) chloride (7791-12-0), Thallium (I) nitrate (10102-45-1), and Thallium (I) sulfate (7446-18-6)
# Provisional Peer Reviewed Toxicity Values for Thiocyanates (Multiple CASRNs)
# Provisional Peer-Reviewed Toxicity Values for Thiocyanic Acid (CASRN 463-56-9, 80864-27-3)
# Provisional Peer-Reviewed Toxicity Values for Thiodiglycol (CASRN 111-48-8)
# Provisional Peer Reviewed Toxicity Values for Thiophene (CASRN 110-02-1)
# Provisional Peer-Reviewed Toxicity Values for Titanium (CASRN 7440-32-6)
# Provisional Peer-Reviewed Toxicity Values for Toluene-2,5-diamine (CASRN 95-70-5) and Compounds Toluene-2,5-diamine sulfate (6369-59-1) [also known as 1,4-Benzenediamine-2-methyl sulfate or 2-Methylbenzene-1,4-diamine sulfate (615-50-9)], Toluene-2,5-diamine dihydrochloride (615-45-2), and Toluene-2,5-diamine monohydrochloride (74612-12-7)
# Provisional Peer-Reviewed Toxicity Values for Toluene-2,5-diamine (CASRN 95-70-5) and Compounds Toluene-2,5-diamine sulfate (6369-59-1) [also known as 1,4-Benzenediamine-2-methyl sulfate or 2-Methylbenzene-1,4-diamine sulfate (615-50-9)], Toluene-2,5-diamine dihydrochloride (615-45-2), and Toluene-2,5-diamine monohydrochloride (74612-12-7)
# Provisional Peer-Reviewed Toxicity Values for Toluene-2,5-diamine (CASRN 95-70-5) and Compounds Toluene-2,5-diamine sulfate (6369-59-1) [also known as 1,4-Benzenediamine-2-methyl sulfate or 2-Methylbenzene-1,4-diamine sulfate (615-50-9)], Toluene-2,5-diamine dihydrochloride (615-45-2), and Toluene-2,5-diamine monohydrochloride (74612-12-7)
# Provisional Peer-Reviewed Toxicity Values for 2,3-Toluenediamine (CASRN 2687-25-4)
# Provisional Peer Reviewed Toxicity Values for 2,6-Toluenediamine (CASRN 823-40-5)
# Provisional Peer-Reviewed Toxicity Values for 3,4-Toluenediamine (CASRN 496-72-0)
# Provisional Peer-Reviewed Subchronic Toxicity Values for Toluene (CASRN 108-88-3)
# Provisional Peer-Reviewed Toxicity Values for p-Toluic Acid (CASRN 99-94-5)
# Provisional Peer-Reviewed Toxicity Values for o-Toluidine (CASRN 95-53-4)
# Provisional Peer-Reviewed Toxicity Values for p-Toluidine (CASRN 106-49-0)
# Provisional Peer-Reviewed Toxicity Values for Complex Mixtures of Aliphatic and Aromatic Hydrocarbons (CASRN Various)
# Provisional Peer-Reviewed Toxicity Values for Complex Mixtures of Aliphatic and Aromatic Hydrocarbons (CASRN Various)
# Provisional Peer-Reviewed Toxicity Values for Complex Mixtures of Aliphatic and Aromatic Hydrocarbons (CASRN Various)
# Provisional Peer-Reviewed Toxicity Values for Complex Mixtures of Aliphatic and Aromatic Hydrocarbons (CASRN Various)
# Provisional Peer-Reviewed Toxicity Values for Complex Mixtures of Aliphatic and Aromatic Hydrocarbons (CASRN Various)
# Provisional Peer-Reviewed Toxicity Values for Complex Mixtures of Aliphatic and Aromatic Hydrocarbons (CASRN Various)
# Provisional Peer-Reviewed Toxicity Values for Technical Toxaphene (CASRN 8001-35-2) Weathered Toxaphene, and Toxaphene Congeners
# Provisional Peer-Reviewed Toxicity Values for Technical Toxaphene (CASRN 8001-35-2) Weathered Toxaphene, and Toxaphene Congeners
# Provisional Peer-Reviewed Toxicity Values for Triacetin (CASRN 102-76-1)
# Provisional Peer-Reviewed Toxicity Values for 2,4,6-Tribromophenol (CASRN 118-79-6)
# Provisional Peer-Reviewed Toxicity Values for Tributyl phosphate (CASRN 126-73-8)
# Provisional Peer-Reviewed Toxicity Values for Tricaine Methanesulfonate (CASRN 886-86-2)
# Provisional Peer-Reviewed Toxicity Values for Calcium Salts of Inorganic Phosphates (Multiple CASRNs)
# Provisional Peer-Reviewed Toxicity Values for 1,1,2-Trichloro-1,2,2-trifluoroethane (CASRN 76-13-1)
# Provisional Peer-Reviewed Toxicity Values for 2,4,6-Trichloroaniline (CASRN 634-93-5) and 2,4,6-Trichloroaniline Hydrochloride (CASRN 33663-50-2)
# Provisional Peer-Reviewed Toxicity Values for 1,2,3-Trichlorobenzene (CASRN 87-61-6)
# Provisional Peer-Reviewed Toxicity Values for 1,2,4-Trichlorobenzene (CASRN 120-82-1)
# Provisional Peer-Reviewed Toxicity Values for 1,1,2-Trichloroethane (CASRN 79-00-5)
# Provisional Peer-Reviewed Toxicity Values for Trichlorofluoromethane (CASRN 75-69-4)
# Provisional Peer Reviewed Toxicity Values for 2, 4, 5-Trichlorophenol (CASRN 95-95-4)
# Provisional Peer Reviewed Toxicity Values for 2,4,6-Trichlorophenol (CASRN 88-06-2)
# Provisional Peer-Reviewed Toxicity Values for 1,1,2-Trichloropropane (CASRN 598-77-6)
# Provisional Peer-Reviewed Toxicity Values for 1,2,3-Trichloropropene (CASRN 96-19-5)
# Provisional Peer Reviewed Toxicity Values for 2,3,6-Trichlorotoluene (CASRN 2077-46-5)
# Provisional Peer Reviewed Toxicity Values for (cid:34)-2,6-Trichlorotoluene (CASRN 2014-83-7)
# Provisional Peer-Reviewed Toxicity Values for Tridymite (CASRN 15468-32-3)
# Provisional Peer-Reviewed Toxicity Values for Triethylene Glycol (CASRN 112-27-6)
# Provisional Peer-Reviewed Toxicity Values for 1,1,1-Trifluoroethane (CASRN 420-46-2)
# Provisional Peer-Reviewed Toxicity Values for Trimethyl Phosphate (CASRN 512-56-1)
# Provisional Peer-Reviewed Toxicity Values for 1,2,3-Trimethyl-4-Propenylnaphthalene (CASRN 26137-53-1)
# Provisional Peer-Reviewed Toxicity Values for 1,2,3-Trimethylbenzene (CASRN 526-73-8)
# Provisional Peer Reviewed Toxicity Values for 1,2,4-Trimethylbenzene (CASRN 95-63-6)
# Provisional Peer-Reviewed Toxicity Values for 1,3,5-Trimethylbenzene (CASRN 108-67-8)
# Provisional Peer-Reviewed Toxicity Values for 2,4,4-Trimethylpentene (CASRN 25167-70-8)
# Provisional Peer-Reviewed Toxicity Values for Trinitrophenylmethylnitramine (CASRN 479-45-8)
# Provisional Peer Reviewed Toxicity Values for Triphenylphosphine oxide (CASRN 791-28-6)
# Provisional Peer-Reviewed Toxicity Values for Tris(1-chloro-2-propyl)phosphate (CASRN 13674-84-5)
# Provisional Peer-Reviewed Toxicity Values for Tris(2-chloroethyl)phosphate (TCEP) (CASRN 115-96-8)
# Provisional Peer Reviewed Toxicity Values for Tris(2-ethylhexyl)phosphate (CASRN 78-42-2)
# Provisional Peer-Reviewed Toxicity Values for Tris(3-chloro-1-propyl)
# Provisional Peer-Reviewed Toxicity Values for Soluble Tungsten Compounds (Various CASRNs)
# Provisional Peer Reviewed Toxicity Values for Vanadium pentoxide (CASRN 1314-62-1)
# Provisional Peer-Reviewed Toxicity Values for Vanadium and Its Soluble Inorganic Compounds Other Than Vanadium Pentoxide (CASRN 7440-62-2 and Others)
# Provisional Peer-Reviewed Toxicity Values for Vinyl Bromide (CASRN 593-60-2)
# Provisional Peer-Reviewed Toxicity Values for White Mineral Oil (CASRN 8012-95-1 and 8020-83-5)
# Provisional Peer-Reviewed Toxicity Values for Xylenes (CASRN 1330-20-7)
# Provisional Peer-Reviewed Toxicity Values for Soluble Zirconium Compounds (CASRN 7440-67-7)
# All done!!!

# %%
#Save the final clowder log after filling in all of this metadata
#Script practice was run with temrporary sheet with non standard column names. Need to rename them
df.rename(columns={'file_name': 'File Name', 'url': 'URL', 'doi':'DOI', 'hero_id':'HERO ID', 'source':'Source', 'subsource':'Subsource','year':'Year','study_name':'Study Name','dsstox_structure_id':'DSSTox Structure ID','author':'Author'}, inplace=True)
out_path = "L:\\PRIV\\ToxValDB\\Upload to Clowder\\Clowder Logs\\clowder_log_source_pprtv_ornl_08032022_metadata_mmille16.xlsx"
with pd.ExcelWriter(out_path) as writer:
    df.to_excel(writer, index = False)
